# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
import nltk

# %%
df=pd.read_csv(r"mobile.csv")
df
# Out:
#      Unnamed: 0                                              title      price  \
# 0             0  OnePlus Nord CE 5G (Blue Void 8GB RAM 128GB St...  ₹45900.00
# 1             1  Samsung Galaxy M42 5G (Prism Dot Black 8GB RAM...   ₹9490.00
# 2             2  Vivo Y20G 2021 (Obsidiant Black 4GB RAM 64GB S...  ₹44000.00
# 3             3  Redmi Note 9 (Arctic White 4GB RAM 64GB Storag...  ₹21490.00
# 4             4  Realme 8 Pro (Infinite Blue, 8GB RAM, 128GB St...  ₹39999.00
# ..          ...                                                ...        ...
# 259         259  Redmi 9 Prime (Matte Black 4GB RAM 64GB Storag...  ₹44990.00
# 260         260  OnePlus Nord CE 5G (Charcoal Ink 12GB RAM 256G...  ₹43999.00
# 261         261  BOLLYWOOD COLLECTION Jio Phone 3 Model 2021  B...  ₹13990.00
# 262         262  Redmi Note 10 (Shadow Black 4GB RAM 64GB Stora...  ₹12999.00
# 263         263  iQOO 7 5G (Storm Black 8GB RAM 256GB Storage)|...  ₹30188.00
#
#                  rating  total_reviews    availability_status  \
# 0    4.2 out of 5 stars      4 ratings  Only 1 left in stock.
# 1    4.3 out of 5 stars     47 ratings              In stock.
# 2    4.2 out of 5 stars    327 ratings              In stock.
# 3    4.3 out of 5 stars  11236 ratings              In stock.
# 4    4.4 out of 5 stars   1238 ratings              In stock.
# ..                  ...            ...                    ...
# 259  4.2 out of 5 stars   2463 ratings              In stock.
# 260  4.2 out of 5 stars   1238 ratings              In stock.
# 261  4.2 out of 5 stars  85525 ratings          Out of stock.
# 262  4.2 out of 5 stars   4986 ratings              In stock.
# 263  4.2 out of 5 stars   1396 ratings  Only 1 left in stock.
#
#                                           manufacturer country_of_origin  \
# 0                                Samsung India pvt Ltd             India
# 1                                              OnePlus             India
# 2                    Oppo Mobiles India Privte Limited             India
# 3                           OPPO Mobiles India Pvt Ltd             India
# 4    Bhagwati Products Ltd. SP1-1 Industrial Area K...             India
# ..                                                 ...               ...
# 259                                               iQOO             India
# 260                                          G Mobiles             India
# 261                                               iQOO             India
# 262                                            OnePlus             India
# 263                                             Xiaomi             India
#
#                os    ram      product_dimensions      weight  \
# 0         Android   6 GB     16.5 x 7.6 x 0.7 cm   167 Grams
# 1         Android   8 GB         15 x 1 x 7.5 cm   161 Grams
# 2    Android 10.0   8 GB     16.3 x 7.5 x 0.8 cm   196 Grams
# 3         Android  32 MB     16.1 x 7.6 x 0.9 cm   175 Grams
# 4         Android   4 GB     15.4 x 0.9 x 7.4 cm   199 Grams
# ..            ...    ...                     ...         ...
# 259       Android   6 GB  16.39 x 7.53 x 0.85 cm   205 Grams
# 260       Android  12 GB  0.77 x 7.32 x 15.86 cm   173 Grams
# 261       Android  12 GB     16.5 x 0.9 x 7.7 cm   172 Grams
# 262   Android 9.0   8 GB       16 x 7.4 x 0.7 cm   198 Grams
# 263       Android   6 GB     16.5 x 0.9 x 7.7 cm   190 Grams
#
#                                             batteries  \
# 0    1 Lithium Polymer batteries required. (included)
# 1    1 Lithium Polymer batteries required. (included)
# 2    1 Lithium Polymer batteries required. (included)
# 3        1 Lithium ion batteries required. (included)
# 4                  1 A batteries required. (included)
# ..                                                ...
# 259                1 A batteries required. (included)
# 260                1 A batteries required. (included)
# 261  1 Lithium Polymer batteries required. (included)
# 262  1 Lithium Polymer batteries required. (included)
# 263  1 Lithium Polymer batteries required. (included)
#
#                                       special_features        form_factor  \
# 0    Dual Bluetooth Audio, IR Blaster, X-Axis Hapti...  Touchscreen Phone
# 1                                             Dual SIM         Smartphone
# 2        Front Camera, Dual_Sim, Camera, Fast Charging                Bar
# 3    Fast Charging Support, Dual SIM, Fingerprint S...                Bar
# 4    Dual SIM, Infrared, E-mail, Accelerometer, Amb...  Touchscreen Phone
# ..                                                 ...                ...
# 259  Dual Stereo Speakers with Dolby Atmos support,...  Touchscreen Phone
# 260  Dual Stereo Speakers for immersive audio exper...  Touchscreen Phone
# 261  Reading Mode, Night Mode, Vibrant colour, GPS,...                Bar
# 262  Dual SIM, Vibration motor, Ambient light senso...  Touchscreen Phone
# 263  Dual SIM, 20, 9 aspect ratio, GPS, Virtual Pro...                Bar
#
#              colour  battery_power_rating  \
# 0    Midnight Black                6000.0
# 1       Prism Black                4400.0
# 2     Galactic Blue                4500.0
# 3        Aqua Green                4000.0
# 4         Champagne                6000.0
# ..              ...                   ...
# 259    Glacier Blue                4500.0
# 260             Red                5000.0
# 261       Jazz Blue                  22.0
# 262           Ocean                4520.0
# 263     Nordic Blue                5000.0
#
#                                    product_description  \
# 0    Redmi 9A comes with Octa-core Helio G25 proces...
# 1    The product comes in a very proper packaging. ...
# 2    Samsung Galaxy M42 5G is Samsung's #FastestMon...
# 3    Spark 7T is a segment leading high performer w...
# 4    13MP Main Camera + 2MP Depth Camera + 2 MP Mac...
# ..                                                 ...
# 259  The Vivo V21 smartphone comes with 64MP+8MP+2M...
# 260  Oxygen OS based on Android v10 operating syste...
# 261  Designed to impress you with its speed the Sam...
# 262  Get ready to experience download speeds 10x hi...
# 263  Redmi 9A comes with Octa-core Helio G25 proces...
#
#                                                reviews  \
# 0    Adequate ..|| Once again proves they sale the ...
# 1    Poor screen quality|| Don't Fall on Youtubers ...
# 2    Very good phone with excellent features and pe...
# 3    Front Camera is bad.|| Save yourself and don't...
# 4    Camera Beast 😍😍|| Vivo X60 Pro Review|| perfec...
# ..                                                 ...
# 259  I prefer you must buy it.|| Best budget smart ...
# 260  Loved it! Only unboxed & all original accessor...
# 261  Phone is not good|| About to small Android ver...
# 262  I am luckiest to have this elegant self create...
# 263  Don't go for it!|| Camera and Dolby sound|| No...
#
#                                         reviews_rating
# 0    3.0 out of 5 stars|| 1.0 out of 5 stars|| 4.0 ...
# 1    1.0 out of 5 stars|| 1.0 out of 5 stars|| 1.0 ...
# 2    5.0 out of 5 stars|| 5.0 out of 5 stars|| 5.0 ...
# 3    4.0 out of 5 stars|| 1.0 out of 5 stars|| 4.0 ...
# 4    4.0 out of 5 stars|| 5.0 out of 5 stars|| 4.0 ...
# ..                                                 ...
# 259  1.0 out of 5 stars|| 5.0 out of 5 stars|| 5.0 ...
# 260  1.0 out of 5 stars|| 1.0 out of 5 stars|| 5.0 ...
# 261  2.0 out of 5 stars|| 5.0 out of 5 stars|| 1.0 ...
# 262  2.0 out of 5 stars|| 5.0 out of 5 stars|| 4.0 ...
# 263  5.0 out of 5 stars|| 1.0 out of 5 stars|| 4.0 ...
#
# [264 rows x 20 columns]

# %%
sentence=df["reviews"][2]
print(sentence)
# Out:
# Very good phone with excellent features and performance.|| I gift To My Father|| 6000mah excellent battery|| Value for money.|| Highly recommended 👌|| Nazro|| It's amazing 😍|| Good|| Nice mobile|| Worst phone ever .. bad display  internally damaged and service centre is worst

# %%
import nltk
nltk.download('punkt_tab')
tokens=nltk.word_tokenize(sentence)
print(tokens)
# Out:
# ['Very', 'good', 'phone', 'with', 'excellent', 'features', 'and', 'performance.||', 'I', 'gift', 'To', 'My', 'Father||', '6000mah', 'excellent', 'battery||', 'Value', 'for', 'money.||', 'Highly', 'recommended', '👌||', 'Nazro||', 'It', "'s", 'amazing', '😍||', 'Good||', 'Nice', 'mobile||', 'Worst', 'phone', 'ever', '..', 'bad', 'display', 'internally', 'damaged', 'and', 'service', 'centre', 'is', 'worst']
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Pratham\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {"didn't", 'ma', 'any', 'both', "i've", 'few', 'haven', 'herself', 'mustn', 'a', 'mightn', 'than', 'below', 'weren', "it'll", 'off', 'have', 'nor', 'don', 'not', 'who', "you'll", 'yourselves', 'before', "that'll", 'for', "haven't", "you've", 'isn', 'his', 'such', 'needn', "he's", 'out', 'if', 'no', "they'll", 'and', 'can', 'until', 'had', 'm', 'too', 'is', 'hadn', 'ourselves', "doesn't", 'couldn', 'but', 'am', 'were', 'you', "won't", 'being', 'there', 'some', 'own', 'about', "mightn't", 'd', 'themselves', 're', 'under', 'been', 'shan', 'll', 'after', 'him', "couldn't", 'other', 'where', "shan't", 'to', "wasn't", 'most', 'same', "we'll", "i'll", 'our', 'against', 'was', 'myself', "it's", 'theirs', 'what', 'that', "they're", 'has', 'each', "she'll", 'me', 'we', 'once', 'when', 'just', 'or', 'them', 't', 'so', 've', "we'd", 'yours', 'because', 'why', 'between', 'whom', 'through', 'now', 'very', 'y', "aren't", "don't", 'those', "mustn't", 'hasn', 'over', 'further', 'are', 'during', 'i', 'will', "wouldn't", 'by', "hasn't", 'it', 'do', 'doing', "i'm", 'on', "you're", "she's", 'then', "we're", 'aren', 'ours', "shouldn't", 'o', "i'd", 'be', 'above', 'these', 'which', 'in', 'from', 'itself', 'hers', "they've", 'does', 'as', 'the', 'into', "he'd", 'more', 'my', "you'd", 'wouldn', "should've", 'didn', 'did', 'their', 'having', 'wasn', 'down', 'doesn', 'its', "hadn't", 'up', 'yourself', 'he', "needn't", "they'd", 'with', 'her', 'they', 'an', 'of', "isn't", 'ain', 'she', 'while', 'himself', "we've", 'all', 'this', "weren't", 'at', 'here', 's', 'your', 'how', "she'd", 'only', 'won', 'shouldn', 'again', 'should', "it'd", "he'll"}

# %%
result=[i for i in tokens if not i in stop_words]
print(result)
# Out:
# ['Very', 'good', 'phone', 'excellent', 'features', 'performance.||', 'I', 'gift', 'To', 'My', 'Father||', '6000mah', 'excellent', 'battery||', 'Value', 'money.||', 'Highly', 'recommended', '👌||', 'Nazro||', 'It', "'s", 'amazing', '😍||', 'Good||', 'Nice', 'mobile||', 'Worst', 'phone', 'ever', '..', 'bad', 'display', 'internally', 'damaged', 'service', 'centre', 'worst']
